# %%
# Import all required modules
# Disable warnings
import warnings

import numpy as np
import pandas as pd

warnings.filterwarnings("ignore")

# Import plotting modules and set up
import seaborn as sns

sns.set()
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.ticker

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# Tune the visual settings for figures in `seaborn`
sns.set_context(
    "notebook", font_scale=1.5, rc={"figure.figsize": (11, 8), "axes.titlesize": 18}
)

from matplotlib import rcParams

rcParams["figure.figsize"] = 11, 8

# %%
data = pd.read_csv("data.csv")
df = pd.DataFrame(data)
data.head(10)
# Out:
#   user_name  description  amount      type        date
# 0      taha       salary     500    Income  2024-05-20
# 1      taha  electrisity      50  Expensis  2024-05-20
# 2      taha           sa     800    Income  2024-05-20
# 3      test           sa    1500    Income  2024-05-20
# 4      test         food      20  Expensis  2024-05-20

# %%
plt.figure(figsize=(12, 10))
sns.FacetGrid(df, hue="type") \
   .map(sns.kdeplot, "amount").add_legend()

# %%
income = df[(df["type"] == 'Income') & (df["user_name"] == 'taha')]
income = income.sort_values(by='date') 
income.head(10)
# Out:
#   user_name description  amount    type        date
# 0      taha      salary     500  Income  2024-05-20
# 2      taha          sa     800  Income  2024-05-20

# %%
data = pd.read_csv("balance.csv")
df = pd.DataFrame(data)
# Filter expenses data
balance = df[df["user_name"] == "taha"]
# Sort expenses by date
balance = balance.sort_values(by='date')
balance.head()
# Out:
#   user_name  balance        date
# 3      taha     1900  2024-05-14
# 2      taha     1300  2024-05-15
# 1      taha     2800  2024-05-18
# 0      taha     2300  2024-05-20
# 4      taha     2370  2024-05-21

# %%
plt.figure()
# Plot line chart of expenses
plt.plot(balance['date'], balance['balance'], marker='o', color="blue") 
plt.xlabel('Date')
plt.ylabel('Balance')
plt.title('Balance Over Time')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
# Out:
# ([0, 1, 2, 3, 4],
#  [Text(0, 0, '2024-05-14'),
#   Text(1, 0, '2024-05-15'),
#   Text(2, 0, '2024-05-18'),
#   Text(3, 0, '2024-05-20'),
#   Text(4, 0, '2024-05-21')])
